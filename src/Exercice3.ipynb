# %%
import sys
print(sys.version)
# Out:
# 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]

# %%
# !pip install torch torchvision
# Out:
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# ...

# %%
# !pip install gensim

# %%
# !pip install OpenNMT-py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.8/262.8 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.3/192.3 MB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.7/56.7 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 14.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 92.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.7/110.7 kB 14.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 94.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 MB 5.0 MB/s eta 0:00:00
# ...

# %%
# !pip install torch==2.3.0 torchvision==0.14.0+cu121 -f https://download.pytorch.org/whl/cu121/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/cu121/torch_stable.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.0/781.0 MB 802.3 kB/s eta 0:00:00
# ERROR: Could not find a version that satisfies the requirement torchvision==0.14.0+cu121 (from versions: 0.1.6, 0.1.7, 0.1.8, 0.1.9, 0.2.0, 0.2.1, 0.2.2, 0.2.2.post2, 0.2.2.post3, 0.12.0, 0.13.0, 0.13.1, 0.14.0, 0.14.1, 0.15.0, 0.15.1, 0.15.2, 0.16.0, 0.16.0+cu121, 0.16.1, 0.16.1+cu121, 0.16.2, 0.16.2+cu121, 0.17.0, 0.17.0+cu121, 0.17.1, 0.17.1+cu121, 0.17.2, 0.17.2+cu121, 0.18.0, 0.18.0+cu121)
# ERROR: No matching distribution found for torchvision==0.14.0+cu121

# %%
# !wget https://s3.amazonaws.com/opennmt-trainingdata/toy-ende.tar.gz
# Out:
# --2024-05-25 21:16:28--  https://s3.amazonaws.com/opennmt-trainingdata/toy-ende.tar.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 16.182.39.48, 54.231.128.216, 54.231.129.128, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|16.182.39.48|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1662081 (1.6M) [application/x-gzip]
# Saving to: ‘toy-ende.tar.gz’
#
# toy-ende.tar.gz     100%[===================>]   1.58M  1.44MB/s    in 1.1s
#
# 2024-05-25 21:16:30 (1.44 MB/s) - ‘toy-ende.tar.gz’ saved [1662081/1662081]

# %%
# !tar xf toy-ende.tar.gz

# %%
# %pwd
# %cd content
# Out:
# '/content'

# %%
# !onmt_build_vocab -config toy_en_de_europarl.yaml -n_sample 10000
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/onmt_build_vocab", line 5, in <module>
#     from onmt.bin.build_vocab import main
#   File "/usr/local/lib/python3.10/dist-packages/onmt/__init__.py", line 2, in <module>
#     import onmt.inputters
#   File "/usr/local/lib/python3.10/dist-packages/onmt/inputters/__init__.py", line 7, in <module>
#     from onmt.inputters.text_utils import text_sort_key, process, numericalize, tensorify
#   File "/usr/local/lib/python3.10/dist-packages/onmt/inputters/text_utils.py", line 1, in <module>
#     import torch
#   File "/usr/local/lib/python3.10/dist-packages/torch/__init__.py", line 1477, in <module>
#     from .functional import *  # noqa: F403
#   File "/usr/local/lib/python3.10/dist-packages/torch/functional.py", line 9, in <module>
#     import torch.nn.functional as F
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/__init__.py", line 1, in <module>
#     from .modules import *  # noqa: F403
# ...

# %%
# !onmt_train -config toy_en_de_europarl.yaml
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/onmt_train", line 5, in <module>
#     from onmt.bin.train import main
#   File "/usr/local/lib/python3.10/dist-packages/onmt/__init__.py", line 2, in <module>
#     import onmt.inputters
#   File "/usr/local/lib/python3.10/dist-packages/onmt/inputters/__init__.py", line 8, in <module>
#     from onmt.inputters.text_corpus import ParallelCorpus, ParallelCorpusIterator
#   File "/usr/local/lib/python3.10/dist-packages/onmt/inputters/text_corpus.py", line 5, in <module>
#     from onmt.transforms import TransformPipe
#   File "/usr/local/lib/python3.10/dist-packages/onmt/transforms/__init__.py", line 65, in <module>
#     module = importlib.import_module("onmt.transforms." + file_name)
#   File "/usr/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# ...

# %%
# !onmt_translate -model toy-ende/run/model_step_1000.pt -src toy-ende/Europarl_test_500.tok.true.clean.en -output toy-ende/run/europarl_prediction.txt -verbose
# Out:
# [2024-05-24 20:58:18,703 INFO] Loading checkpoint from toy-ende/run/model_step_1000.pt
# [2024-05-24 20:58:19,377 INFO] Loading data into the model
# [2024-05-24 20:58:49,052 INFO]
# SENT 1: ['it', 'is', 'only', 'fair', 'to', 'acknowledge', 'the', 'extraordinary', 'contribution', 'of', 'this', 'Parliament', '.']
# PRED 1: c &apos; est pourquoi je ne pense pas que le Parlement européen .
# PRED SCORE: -1.0096
#
# [2024-05-24 20:58:49,052 INFO]
# SENT 2: ['for', 'Spain', ',', 'which', 'has', 'fought', 'to', 'maintain', 'the', '<unk>', 'sense', 'and', 'the', 'balance', 'of', 'the', 'Treaty', ',', 'the', 'support', 'of', 'this', 'House', 'has', 'been', 'encouraging', 'and', 'decisive', '.']
# PRED 2: dans ce contexte , je ne pense pas qu&apos; il y a un peu de vue de l&apos; Union européenne .
# PRED SCORE: -1.4018
#
# [2024-05-24 20:58:49,053 INFO]
# SENT 3: ['during', 'the', 'negotiations', ',', 'Europe', 'has', 'kept', 'moving', 'forward', '.']
# ...

# %%
# !onmt_build_vocab -config toy_en_de_europarl_emea.yaml -n_sample 10000
# Out:
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2024-05-24 21:38:02,795 INFO] Counter vocab from 10000 samples.
# [2024-05-24 21:38:02,795 INFO] Build vocab on 10000 transformed examples/corpus.
# [2024-05-24 21:38:03,333 INFO] Counters src: 11818
# [2024-05-24 21:38:03,333 INFO] Counters tgt: 14975
# Traceback (most recent call last):
#   File "/usr/local/bin/onmt_build_vocab", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.10/dist-packages/onmt/bin/build_vocab.py", line 283, in main
#     build_vocab_main(opts)
#   File "/usr/local/lib/python3.10/dist-packages/onmt/bin/build_vocab.py", line 267, in build_vocab_main
#     save_counter(src_counter, opts.src_vocab)
#   File "/usr/local/lib/python3.10/dist-packages/onmt/bin/build_vocab.py", line 256, in save_counter
#     check_path(save_path, exist_ok=opts.overwrite, log=logger.warning)
#   File "/usr/local/lib/python3.10/dist-packages/onmt/utils/misc.py", line 47, in check_path
# ...

# %%
# !onmt_train -config toy_en_de_europarl_emea.yaml
# Out:
# [2024-05-24 21:41:00,911 INFO] Missing transforms field for corpus_1 data, set to default: [].
# [2024-05-24 21:41:00,911 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2024-05-24 21:41:00,911 INFO] Missing transforms field for valid data, set to default: [].
# [2024-05-24 21:41:00,911 INFO] Parsed 2 corpora from -data.
# [2024-05-24 21:41:00,912 INFO] Get special vocabs from Transforms: {'src': [], 'tgt': []}.
# [2024-05-24 21:41:00,978 INFO] The first 10 tokens of the vocabs are:['<unk>', '<blank>', '<s>', '</s>', 'the', ',', '.', 'of', 'to', 'and']
# [2024-05-24 21:41:00,978 INFO] The decoder start token is: <s>
# [2024-05-24 21:41:00,978 INFO] Building model...
# [2024-05-24 21:41:02,057 INFO] Switching model to float32 for amp/apex_amp
# [2024-05-24 21:41:02,058 INFO] Non quantized layer compute is fp32
# [2024-05-24 21:41:02,063 INFO] NMTModel(
#   (encoder): RNNEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
# ...

# %%
# !onmt_translate -model toy-ende/run/model_step_1000.pt -src toy-ende/Europarl_test_500.tok.true.clean.en -output toy-ende/run/europarl_emea_prediction.txt -verbose
# Out:
# [2024-05-24 23:37:23,532 INFO] Loading checkpoint from toy-ende/run/model_step_1000.pt
# [2024-05-24 23:37:24,306 INFO] Loading data into the model
# [2024-05-24 23:38:11,851 INFO]
# SENT 1: ['it', 'is', 'only', 'fair', 'to', 'acknowledge', 'the', 'extraordinary', 'contribution', 'of', 'this', 'Parliament', '.']
# PRED 1: il s&apos; agit d&apos; une question de l&apos; Union européenne .
# PRED SCORE: -1.0139
#
# [2024-05-24 23:38:11,851 INFO]
# SENT 2: ['for', 'Spain', ',', 'which', 'has', 'fought', 'to', 'maintain', 'the', '<unk>', 'sense', 'and', 'the', 'balance', 'of', 'the', 'Treaty', ',', 'the', 'support', 'of', 'this', 'House', 'has', 'been', 'encouraging', 'and', 'decisive', '.']
# PRED 2: la question de la commission de la concurrence de la concurrence de la concurrence de l &apos; Union européenne et de la sécurité de l &apos; emploi et de l &apos; environnement .
# PRED SCORE: -1.2955
#
# [2024-05-24 23:38:11,852 INFO]
# ...
