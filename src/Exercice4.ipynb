# %%
import sys
print(sys.version)
# Out:
# 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]

# %%
# !pip install torch torchvision
# Out:
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# ...

# %%
# !pip install gensim

# %%
# !pip install OpenNMT-py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.8/262.8 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.3/192.3 MB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.7/56.7 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 58.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 14.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 66.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.7/110.7 kB 16.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 74.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 MB 7.3 MB/s eta 0:00:00
# ...

# %%
# !pip install torch==2.3.0 torchvision==0.14.0+cu121 -f https://download.pytorch.org/whl/cu121/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/cu121/torch_stable.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.0/781.0 MB 2.0 MB/s eta 0:00:00
# ERROR: Could not find a version that satisfies the requirement torchvision==0.14.0+cu121 (from versions: 0.1.6, 0.1.7, 0.1.8, 0.1.9, 0.2.0, 0.2.1, 0.2.2, 0.2.2.post2, 0.2.2.post3, 0.12.0, 0.13.0, 0.13.1, 0.14.0, 0.14.1, 0.15.0, 0.15.1, 0.15.2, 0.16.0, 0.16.0+cu121, 0.16.1, 0.16.1+cu121, 0.16.2, 0.16.2+cu121, 0.17.0, 0.17.0+cu121, 0.17.1, 0.17.1+cu121, 0.17.2, 0.17.2+cu121, 0.18.0, 0.18.0+cu121)
# ERROR: No matching distribution found for torchvision==0.14.0+cu121

# %%
# !wget https://s3.amazonaws.com/opennmt-trainingdata/toy-ende.tar.gz
# Out:
# --2024-05-26 08:14:05--  https://s3.amazonaws.com/opennmt-trainingdata/toy-ende.tar.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.216.192, 52.217.92.6, 52.217.115.208, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.216.192|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1662081 (1.6M) [application/x-gzip]
# Saving to: ‘toy-ende.tar.gz.1’
#
# toy-ende.tar.gz.1   100%[===================>]   1.58M  4.23MB/s    in 0.4s
#
# 2024-05-26 08:14:06 (4.23 MB/s) - ‘toy-ende.tar.gz.1’ saved [1662081/1662081]

# %%
# !tar xf toy-ende.tar.gz

# %%
print('bonjour nico')
# Out:
# bonjour nico

# %%
print('Coucou Constance~')
# Out:
# Coucou Constance~

# %%
# !onmt_build_vocab -config lemma_run1_exo4.yaml -n_sample 10000
# Out:
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2024-05-26 08:47:13,667 INFO] Counter vocab from 10000 samples.
# [2024-05-26 08:47:13,667 INFO] Build vocab on 10000 transformed examples/corpus.
# [2024-05-26 08:47:14,422 INFO] Counters src: 9268
# [2024-05-26 08:47:14,426 INFO] Counters tgt: 12887

# %%
# !onmt_train -config lemma_run1_exo4.yaml
# Out:
# [2024-05-26 08:47:56,267 INFO] Missing transforms field for corpus_1 data, set to default: [].
# [2024-05-26 08:47:56,267 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2024-05-26 08:47:56,267 INFO] Missing transforms field for valid data, set to default: [].
# [2024-05-26 08:47:56,267 INFO] Parsed 2 corpora from -data.
# [2024-05-26 08:47:56,267 INFO] Get special vocabs from Transforms: {'src': [], 'tgt': []}.
# [2024-05-26 08:47:56,320 INFO] The first 10 tokens of the vocabs are:['<unk>', '<blank>', '<s>', '</s>', 'the', ',', 'be', '.', 'of', 'to']
# [2024-05-26 08:47:56,321 INFO] The decoder start token is: <s>
# [2024-05-26 08:47:56,321 INFO] Building model...
# [2024-05-26 08:47:57,860 INFO] Switching model to float32 for amp/apex_amp
# [2024-05-26 08:47:57,861 INFO] Non quantized layer compute is fp32
# [2024-05-26 08:47:57,867 INFO] NMTModel(
#   (encoder): RNNEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
# ...

# %%
# !onmt_translate -model toy-ende/run/model_step_1000.pt -src toy-ende/lemma_Europarl_test_500.tok.true.clean.en -output toy-ende/run/run1_exo4_prediction.txt -verbose
# Out:
# [2024-05-26 11:07:24,676 INFO] Loading checkpoint from toy-ende/run/model_step_1000.pt
# [2024-05-26 11:07:25,355 INFO] Loading data into the model
# [2024-05-26 11:08:31,049 INFO]
# SENT 1: ['it', 'be', 'only', 'fair', 'to', 'acknowledge', 'the', 'extraordinary', 'contribution', 'of', 'this', 'Parliament', '.']
# PRED 1: c & apos ; est pourquoi il est important d & apos ; une base d & apos ; un état membre
# PRED SCORE: -1.1090
#
# [2024-05-26 11:08:31,049 INFO]
# SENT 2: ['for', 'Spain', ',', 'which', 'have', 'fight', 'to', 'maintain', 'the', '<unk>', 'sense', 'and', 'the', 'balance', 'of', 'the', 'Treaty', ',', 'the', 'support', 'of', 'this', 'House', 'have', 'be', 'encourage', 'and', 'decisive', '.']
# PRED 2: en effet , il y a de nombreuses possibilité d & apos ; état de vue de l & apos ; union européen en matière d & apos ; énergie de l & apos ; union européen et de l &
# PRED SCORE: -1.2127
#
# [2024-05-26 11:08:31,049 INFO]
# ...

# %%
# !onmt_build_vocab -config lemma_run2_exo4.yaml -n_sample 10000
# Out:
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2024-05-26 11:13:15,750 INFO] Counter vocab from 10000 samples.
# [2024-05-26 11:13:15,750 INFO] Build vocab on 10000 transformed examples/corpus.
# [2024-05-26 11:13:16,304 INFO] Counters src: 9529
# [2024-05-26 11:13:16,304 INFO] Counters tgt: 13149

# %%
# !onmt_train -config lemma_run2_exo4.yaml
# Out:
# [2024-05-26 11:13:34,037 INFO] Missing transforms field for corpus_1 data, set to default: [].
# [2024-05-26 11:13:34,037 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2024-05-26 11:13:34,037 INFO] Missing transforms field for valid data, set to default: [].
# [2024-05-26 11:13:34,037 INFO] Parsed 2 corpora from -data.
# [2024-05-26 11:13:34,037 INFO] Get special vocabs from Transforms: {'src': [], 'tgt': []}.
# [2024-05-26 11:13:34,097 INFO] The first 10 tokens of the vocabs are:['<unk>', '<blank>', '<s>', '</s>', 'the', ',', 'be', '.', 'of', 'to']
# [2024-05-26 11:13:34,098 INFO] The decoder start token is: <s>
# [2024-05-26 11:13:34,098 INFO] Building model...
# [2024-05-26 11:13:34,751 INFO] Switching model to float32 for amp/apex_amp
# [2024-05-26 11:13:34,751 INFO] Non quantized layer compute is fp32
# [2024-05-26 11:13:34,752 INFO] NMTModel(
#   (encoder): RNNEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
# ...

# %%
# !onmt_translate -model toy-ende/run/model_step_1000.pt -src toy-ende/lemma_Europarl_test_500.tok.true.clean.en -output toy-ende/run/run2_exo4_prediction.txt -verbose
# Out:
# [2024-05-26 13:26:22,104 INFO] Loading checkpoint from toy-ende/run/model_step_1000.pt
# [2024-05-26 13:26:22,825 INFO] Loading data into the model
# [2024-05-26 13:27:01,759 INFO]
# SENT 1: ['it', 'be', 'only', 'fair', 'to', 'acknowledge', 'the', 'extraordinary', 'contribution', 'of', 'this', 'Parliament', '.']
# PRED 1: c & apos ; est la raison de l & apos ; union européen .
# PRED SCORE: -0.8042
#
# [2024-05-26 13:27:01,759 INFO]
# SENT 2: ['for', 'Spain', ',', 'which', 'have', 'fight', 'to', 'maintain', 'the', '<unk>', 'sense', 'and', 'the', 'balance', 'of', 'the', 'Treaty', ',', 'the', 'support', 'of', 'this', 'House', 'have', 'be', 'encourage', 'and', 'decisive', '.']
# PRED 2: en ce qui concerne l & apos ; union européen , la commission ne doit pas être adopté dans le cadre de l & apos ; union .
# PRED SCORE: -1.2534
#
# [2024-05-26 13:27:01,759 INFO]
# SENT 3: ['during', 'the', 'negotiation', ',', 'Europe', 'have', 'keep', 'move', 'forward', '.']
# ...
